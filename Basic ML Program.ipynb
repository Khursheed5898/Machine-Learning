# %%
import math
print(math.factorial(8))
# Out:
# 40320

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn import tree
features = [130,0] , [140,0] ,[]
labels = [0,0,1,1]

# %%
clf=fit. DecisionTreeClassifier

# %%
l=[2,3,4,12,34,14,11]
l.sort()
print(l)
# Out:
# [2, 3, 4, 11, 12, 14, 34]

# %%
import math as m
m.cos(3.14)
# Out:
# -0.9999987317275395
